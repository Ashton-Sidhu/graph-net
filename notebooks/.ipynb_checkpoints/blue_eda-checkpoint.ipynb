# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
blue_df = pd.read_json('D:/sysmon.json', lines=True, chunksize=100000)
red_df = pd.read_json('D:\empire_apt3_2019-05-14223117.json', lines=True)

# %%
import json

with open('D:/empire_apt3_2019-05-14223117.json') as f:
    data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-2076a8d63454> in <module>
#       1 import json
#       2
# ----> 3 with open('D:/empire_apt3_2019-05-14223117.json') as f:
#       4     data = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/empire_apt3_2019-05-14223117.json'

# %%
red_df = pd.read_json('D:\empire_apt3_2019-05-14223117.json', lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d883680c1d52> in <module>
# ----> 1 red_df = pd.read_json('D:\empire_apt3_2019-05-14223117.json', lines=True)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/json/_json.py in read(self)
#     713         elif self.lines:
#     714             data = ensure_str(self.data)
# --> 715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# ...

# %%
blue_df = next(df)

# %%
blue_df = pd.io.json.json_normalize(blue_df['_source'])

# %%
blue_df
# Out:
#                      @timestamp  \
# 0      2019-10-17T04:20:46.168Z
# 1      2019-10-17T04:20:46.168Z
# 2      2019-10-17T04:20:46.168Z
# 3      2019-10-17T04:20:46.168Z
# 4      2019-10-17T04:20:46.168Z
# ...                         ...
# 99995  2019-10-17T18:59:37.601Z
# 99996  2019-10-17T18:59:37.602Z
# 99997  2019-10-17T18:59:37.602Z
# 99998  2019-10-17T18:59:37.602Z
# 99999  2019-10-17T18:59:37.602Z
#
#                                                  message ecs.version  \
# 0      Network connection detected:\nRuleName: \nUtcT...       1.1.0
# 1      Network connection detected:\nRuleName: \nUtcT...       1.1.0
# 2      Network connection detected:\nRuleName: \nUtcT...       1.1.0
# 3      Network connection detected:\nRuleName: \nUtcT...       1.1.0
# 4      Network connection detected:\nRuleName: \nUtcT...       1.1.0
# ...                                                  ...         ...
# 99995  Network connection detected:\nRuleName: \nUtcT...       1.1.0
# ...

# %%
blue_df[~blue_df['winlog.event_data.ParentImage'].isnull()]
# Out:
#                      @timestamp  \
# 58     2019-10-17T04:20:53.636Z
# 59     2019-10-17T04:20:53.642Z
# 60     2019-10-17T04:20:53.643Z
# 61     2019-10-17T04:20:53.645Z
# 62     2019-10-17T04:20:53.649Z
# ...                         ...
# 99846  2019-10-17T18:59:49.373Z
# 99847  2019-10-17T18:59:49.396Z
# 99941  2019-10-17T18:59:50.571Z
# 99942  2019-10-17T18:59:50.587Z
# 99943  2019-10-17T18:59:50.590Z
#
#                                                  message ecs.version  \
# 58     Process Create:\nRuleName: \nUtcTime: 2019-10-...       1.1.0
# 59     Process Create:\nRuleName: \nUtcTime: 2019-10-...       1.1.0
# 60     Process Create:\nRuleName: \nUtcTime: 2019-10-...       1.1.0
# 61     Process Create:\nRuleName: \nUtcTime: 2019-10-...       1.1.0
# 62     Process Create:\nRuleName: \nUtcTime: 2019-10-...       1.1.0
# ...                                                  ...         ...
# 99846  Process Create:\nRuleName: \nUtcTime: 2019-10-...       1.1.0
# ...

# %%
blue_df = blue_df[['winlog.user.name', ]]

# %%
red_df
# Out:
#                       @timestamp  \
# 0       2019-05-14T22:31:14.252Z
# 1       2019-05-14T22:31:14.253Z
# 2       2019-05-14T22:31:14.727Z
# 3       2019-05-14T22:31:15.268Z
# 4       2019-05-14T22:31:15.219Z
# ...                          ...
# 121654  2019-05-14T23:47:44.206Z
# 121655  2019-05-14T23:47:43.692Z
# 121656  2019-05-14T23:47:43.694Z
# 121657  2019-05-14T23:47:44.003Z
# 121658  2019-05-14T23:47:44.206Z
#
#                                                 @metadata  \
# 0       {'beat': 'winlogbeat', 'type': 'doc', 'version...
# 1       {'beat': 'winlogbeat', 'type': 'doc', 'version...
# 2       {'beat': 'winlogbeat', 'type': 'doc', 'version...
# 3       {'beat': 'winlogbeat', 'type': 'doc', 'version...
# 4       {'beat': 'winlogbeat', 'type': 'doc', 'version...
# ...                                                   ...
# 121654  {'beat': 'winlogbeat', 'type': 'doc', 'version...
# 121655  {'beat': 'winlogbeat', 'type': 'doc', 'version...
# ...
